# %%
x = 22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 # Processed on Jupyter Hub

# %% [markdown]
# ![BerneseMountainDog.jpg](attachment:2c778731-9416-4931-a224-d36612a5237a.jpg)

# %%
y = 1

y *= 6
y *= 5
y *= 4
y *= 3
y *= 2
y *= 1
print (y)
# Out:
# 720

# %%
h = 6.626*10**-34
f = 2.42*10**28
c = 3*10**8
l = c/f
E = h*(c/l)
print (E)
# Out:
# 1.6034919999999996e-05

# %%
G = 6.67408*10**(-11)
m_1 = 7.342*10**22
m_2 = 5.9722*10**24
r = 385000.6*10**3

F = (G*m_1*m_2)/r**2
print (F)
# Out:
# 1.9743189716506414e+20

# %%
# Out:
#   Cell In[1], line 1
#     http://localhost:8888/view/Downloads/Schermafbeelding%202026-02-12%20132708.png
#                                                                  ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %% [markdown]
# ![Schermafbeelding%202026-02-12%20132708.png](attachment:Schermafbeelding%202026-02-12%20132708.png)
